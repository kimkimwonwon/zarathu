# %% [raw]
# ---
# title: "Streamlit Tutorial"
# author : "Kim Won"
# format:
#   revealjs:
#     incremental: true
#     auto-animate-easing: ease-in-out
#     auto-animate-unmatched: false
#     auto-animate-duration: 0.8
#     transition: slide
#     background-transition: fade
#     multiplex: true
#     chalkboard:
#       theme: whiteboard
#       boardmarker-width: 5
#       buttons: false
#
# ---

# %% [markdown]
# ## 안녕하세요 {transition="fade-in slide-out"}
#
# 유익하고 즐거운 시간 만들어 드리도록 하겠습니다
#
# -   목차
# -   왜 하게 됐는가?
# -   무엇을 배웠는가? 나는 어떤 예상을 했는가\
# -   졸음쉼터
# -   코드리뷰
# -   스트림릿의 기능 / 샤이니와의 차이 껍데기
# -   plotly vs ggplot
#
# ![img]()
#
# ## 분필모드  {chalkboard-buttons="true"}
#
# Quarto enables you to weave together content and executable code into a finished presentation. To learn more about Quarto presentations see <https://quarto.org/docs/presentations/>.
#
# # 스트림릿 개발 과정 회고
#
# ## Bullets
# ::: {.r-stack}
# ![](image1.png){.fragment width="450" height="300"}
#
# ![](image2.png){.fragment width="300" height="450"}
#
# ![](image3.png){.fragment width="400" height="400"}
# :::
#
# ## streamlit skeleton code
# ```{.python code-line-numbers="6-8"}
# import numpy as np
# import matplotlib.pyplot as plt
#
# r = np.arange(0, 2, 0.01)
# theta = 2 * np.pi * r
# fig, ax = plt.subplots(subplot_kw={'projection': 'polar'})
# ax.plot(theta, r)
# ax.set_rticks([0.5, 1, 1.5, 2])
# ax.grid(True)
# plt.show()
# ```
#
# ## Code {auto-animate=true}
#
#
# ::: {style="margin-top: 100px;"}
#
# 재밌는 놀이
#
# :::
#
# ## Code {auto-animate=true}
# ::: {style="margin-top: 200px; font-size: 3em; color: red;"}
# 재밌는 놀이
# :::
#
# ## 헐
# 안녕하세용
#
# ## 파이썬코드

# %%
#| code-line-numbers: "|6|9"

import numpy as np
import matplotlib.pyplot as plt

r = np.arange(0, 2, 0.01)
theta = 2 * np.pi * r
ax.plot(theta, r)
ax.set_rticks([0.5, 1, 1.5, 2])
ax.grid(True)
plt.show()
